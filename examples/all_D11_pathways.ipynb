# %% [markdown]
# # All D11 Calculation Pathways
#
# This notebook analyzes snow D11 (flexural rigidity in the x-direction) calculation methods at the **slab-level** scale.
#
# ## Table of Contents
#
# 1. [Load Snow Pit Data](#1-load-snow-pit-data)
# 2. [Find All D11 Calculation Pathways](#2-find-all-d11-calculation-pathways)
# 3. [Slab-Level Analysis (ECTP)](#3-slab-level-analysis-ectp)
# 4. [Sankey Diagram: kim_jamieson_table2 → wautier → kochle](#4-sankey-diagram-kim_jamieson_table2--wautier--kochle)
#
# **Target Parameter**: `D11` — slab flexural rigidity in the x-direction (N·m)
#
# D11 is a slab-level property requiring elastic modulus and Poisson's ratio for all layers. Uncertainty reflects propagated input measurement uncertainties only (method regression standard error excluded).

# %%
from pathlib import Path
from typing import Dict, Any
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

from snowpyt_mechparams.snowpilot import parse_caaml_directory
from snowpyt_mechparams.data_structures import Pit, Slab
from snowpyt_mechparams.graph import graph
from snowpyt_mechparams.algorithm import find_parameterizations
from snowpyt_mechparams.execution import ExecutionEngine
from snowpyt_mechparams.execution.config import ExecutionConfig

# %% [markdown]
# ## 1. Load Snow Pit Data

# %%
snow_pits_raw = parse_caaml_directory(str(Path("data")))
pits = [Pit.from_snow_pit(sp) for sp in snow_pits_raw]

print(f"Loaded {len(pits)} snow pits ({sum(len(pit.layers) for pit in pits)} layers)")
# Out:
# Loaded 51138 snow pits (377729 layers)

# %% [markdown]
# ## 2. Find All D11 Calculation Pathways

# %%
pathways = find_parameterizations(graph, graph.get_node("D11"))

print(f"Found {len(pathways)} pathways for calculating D11:\n")
for i, pathway in enumerate(pathways, 1):
    print(f"Pathway {i}:")
    print(pathway)
    print()
# Out:
# Found 32 pathways for calculating D11:
#
# Pathway 1:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 2, branch 3, branch 4: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 2:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 4, branch 5: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 3:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 4:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 5:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 7: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form
# merge branch 4, branch 5, branch 6: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 4, branch 5, branch 6, branch 7: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 6:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 7:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 8:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form
# merge branch 2, branch 3, branch 4: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 2, branch 3, branch 4, branch 5: merge_density_grain_form -- bergfeld --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 9:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 2, branch 3, branch 4: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 10:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 4, branch 5: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 11:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 12:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 13:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 7: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form
# merge branch 4, branch 5, branch 6: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 4, branch 5, branch 6, branch 7: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 14:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 15:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 16:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form
# merge branch 2, branch 3, branch 4: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 2, branch 3, branch 4, branch 5: merge_density_grain_form -- kochle --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 17:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 2, branch 3, branch 4: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 18:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 4, branch 5: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 19:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 20:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 21:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 7: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form
# merge branch 4, branch 5, branch 6: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 4, branch 5, branch 6, branch 7: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 22:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 23:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 24:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form
# merge branch 2, branch 3, branch 4: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 2, branch 3, branch 4, branch 5: merge_density_grain_form -- wautier --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 25:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 2, branch 3, branch 4: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 26:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 4, branch 5: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 27:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 28:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 4, branch 5, branch 6: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 29:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_density -- data_flow --> density -- data_flow --> merge_density_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 4: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 7: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# merge branch 1: zi
# merge branch 2, branch 3: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 4, branch 5: merge_hand_hardness_grain_form
# merge branch 4, branch 5, branch 6: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 4, branch 5, branch 6, branch 7: merge_density_grain_form -- srivastava --> poissons_ratio
# merge branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6, branch 7: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 30:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- geldsetzer --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 31:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 5: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form -- kim_jamieson_table2 --> density
# merge branch 2, branch 3, branch 4: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5: merge_zi_E_nu -- weissgraeber_rosendahl --> D11
#
# Pathway 32:
# branch 1: snow_pit -- data_flow --> measured_layer_thickness -- data_flow --> zi
# branch 2: snow_pit -- data_flow --> measured_hand_hardness -- data_flow --> merge_hand_hardness_grain_form
# branch 3: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_hand_hardness_grain_form
# branch 4: snow_pit -- data_flow --> measured_grain_size -- data_flow --> merge_hand_hardness_grain_form_grain_size
# branch 5: snow_pit -- data_flow --> measured_grain_form -- data_flow --> merge_density_grain_form
# branch 6: snow_pit -- data_flow --> measured_grain_form -- kochle --> poissons_ratio -- data_flow --> merge_E_nu
# merge branch 1: zi
# merge branch 2, branch 3: merge_hand_hardness_grain_form
# merge branch 2, branch 3, branch 4: merge_hand_hardness_grain_form_grain_size -- kim_jamieson_table5 --> density
# merge branch 2, branch 3, branch 4, branch 5: merge_density_grain_form -- schottner --> elastic_modulus
# merge branch 2, branch 3, branch 4, branch 5, branch 6: merge_E_nu
# merge branch 1, branch 2, branch 3, branch 4, branch 5, branch 6: merge_zi_E_nu -- weissgraeber_rosendahl --> D11

# %% [markdown]
# ### Why 32 Pathways, Not More?
#
# D11 requires three layer-level parameters, each with multiple methods:
#
# | Parameter | Methods | Count |
# |-----------|---------|-------|
# | `density` | `data_flow`, `geldsetzer`, `kim_jamieson_table2`, `kim_jamieson_table5` | 4 |
# | `elastic_modulus` | `bergfeld`, `kochle`, `wautier`, `schottner` | 4 |
# | `poissons_ratio` | `kochle`, `srivastava` | 2 |
#
# 4 × 4 × 2 = **32 unique method combinations**.
#
# The `srivastava` Poisson's ratio method requires `density` as input. The algorithm's backward traversal treats the density sub-path for `elastic_modulus` and for `srivastava` as independent choices, generating up to 80 structural traversals. `find_parameterizations` deduplicates them using `_method_fingerprint`, leaving exactly the 32 unique combinations above.

# %% [markdown]
# ## 3. Slab-Level Analysis (ECTP)

# %%
# Create ECTP slabs
ectp_slabs = []
for pit in pits:
    for slab in pit.create_slabs(weak_layer_def="ECTP_failure_layer"):
        ectp_slabs.append({'slab': slab, 'n_layers': len(slab.layers)})

print(f"Created {len(ectp_slabs)} ECTP slabs")
# Out:
# Created 14951 ECTP slabs

# %%
engine = ExecutionEngine(graph)
config = ExecutionConfig(include_method_uncertainty=False)

# For each pathway track per-slab boolean outcomes:
#   density              — all layers computed density
#   e_mod / poissons     — all layers computed E / ν  (independent, parallel)
#   pass_both            — pass E AND pass ν (required for D11)
#   fail_e_only          — pass ν but fail E
#   fail_nu_only         — pass E but fail ν
#   fail_both_ep         — fail both E and ν
#   d11                  — slab D11 computed successfully
pathway_slab_success: Dict[str, int] = {}
pathway_step_counts: Dict[str, Dict[str, int]] = {}
pathway_rel_unc: Dict[str, list] = {}
pathway_nominal: Dict[str, list] = {}

for info in ectp_slabs:
    slab = info['slab']
    n = info['n_layers']
    results = engine.execute_all(slab, "D11", config=config)
    for pathway_result in results.pathways.values():
        density_method = pathway_result.methods_used.get('density', 'unknown')
        e_mod_method   = pathway_result.methods_used.get('elastic_modulus', 'unknown')
        pr_method      = pathway_result.methods_used.get('poissons_ratio', 'unknown')
        full_pathway   = f"{density_method} \u2192 {e_mod_method} \u2192 {pr_method}"

        if full_pathway not in pathway_slab_success:
            pathway_slab_success[full_pathway] = 0
            pathway_step_counts[full_pathway]  = {
                'density': 0,
                'e_mod': 0, 'poissons': 0,
                'pass_both': 0,
                'fail_e_only': 0, 'fail_nu_only': 0, 'fail_both_ep': 0,
                'd11': 0,
            }
            pathway_rel_unc[full_pathway] = []
            pathway_nominal[full_pathway] = []

        traces = pathway_result.computation_trace
        ok_density  = sum(1 for t in traces if t.parameter == "density"         and t.success and t.output is not None) == n
        ok_e_mod    = sum(1 for t in traces if t.parameter == "elastic_modulus" and t.success and t.output is not None) == n
        ok_poissons = sum(1 for t in traces if t.parameter == "poissons_ratio"  and t.success and t.output is not None) == n

        sc = pathway_step_counts[full_pathway]
        if ok_density:  sc['density']  += 1
        if ok_e_mod:    sc['e_mod']    += 1
        if ok_poissons: sc['poissons'] += 1

        # Parallel step breakdown (only meaningful for slabs that passed density)
        if ok_density:
            if   ok_e_mod and ok_poissons:  sc['pass_both']    += 1
            elif ok_e_mod and not ok_poissons: sc['fail_nu_only']  += 1
            elif ok_poissons and not ok_e_mod: sc['fail_e_only']   += 1
            else:                           sc['fail_both_ep'] += 1

        d11_val = d11_std = None
        for trace in traces:
            if trace.parameter == "D11" and trace.success and trace.output is not None:
                out = trace.output
                if hasattr(out, 'nominal_value'):
                    d11_val, d11_std = out.nominal_value, out.std_dev
                else:
                    try:
                        d11_val, d11_std = float(out), 0.0
                    except (TypeError, ValueError):
                        pass
                break

        if d11_val is not None:
            pathway_slab_success[full_pathway] += 1
            sc['d11'] += 1
            pathway_nominal[full_pathway].append(d11_val)
            if d11_val != 0 and d11_std is not None:
                pathway_rel_unc[full_pathway].append(d11_std / d11_val)

print(f"Executed {len(pathways)} pathways on {len(ectp_slabs)} slabs")
# Out:
# Executed 32 pathways on 14951 slabs

# %%
total_slabs = len(ectp_slabs)

# Sort by slab count descending
sorted_pathways = sorted(pathway_slab_success.items(), key=lambda x: x[1], reverse=True)

print(f"  {'Full Pathway':<55s} {'Slabs':>30s} {'Avg Value':>16s} {'Avg Rel. Uncertainty':>22s}")
print(f"  {'-'*125}")
for pathway, n_ok in sorted_pathways:
    slab_str = f"{n_ok} / {total_slabs} ({n_ok / total_slabs:.1%})"
    rel_uncs = pathway_rel_unc.get(pathway, [])
    avg_unc = np.mean(rel_uncs) if rel_uncs else float('nan')
    unc_str = f"{avg_unc:.1%}" if not np.isnan(avg_unc) else "N/A"
    nominals = pathway_nominal.get(pathway, [])
    avg_nom = np.mean(nominals) if nominals else float('nan')
    nom_str = f"{avg_nom:.3e} N·m" if not np.isnan(avg_nom) else "N/A"
    print(f"  {pathway:<55s} {slab_str:>30s}    {nom_str:>14s}    {unc_str:>18s}")

print()
print("  Note: Uncertainty is propagated from input measurement uncertainties only.")
print("  Slab success requires D11 calculation for the entire slab.")
# Out:
#   Full Pathway                                                                     Slabs        Avg Value   Avg Rel. Uncertainty
#   -----------------------------------------------------------------------------------------------------------------------------
#   geldsetzer → wautier → kochle                                       756 / 14951 (5.1%)     2.257e+09 N·m                 38.1%
#   kim_jamieson_table2 → wautier → kochle                              756 / 14951 (5.1%)     2.189e+09 N·m                 37.3%
#   geldsetzer → schottner → kochle                                     756 / 14951 (5.1%)     8.926e+07 N·m                 74.8%
#   kim_jamieson_table2 → schottner → kochle                            756 / 14951 (5.1%)     8.716e+07 N·m                 73.3%
#   geldsetzer → kochle → kochle                                        507 / 14951 (3.4%)     2.489e+08 N·m                 88.0%
#   kim_jamieson_table2 → bergfeld → kochle                             505 / 14951 (3.4%)     6.749e+07 N·m                 75.4%
#   geldsetzer → bergfeld → kochle                                      483 / 14951 (3.2%)     7.064e+07 N·m                 76.9%
#   geldsetzer → wautier → srivastava                                   460 / 14951 (3.1%)     1.663e+09 N·m                 45.2%
#   geldsetzer → schottner → srivastava                                 460 / 14951 (3.1%)     7.096e+07 N·m                 86.7%
#   kim_jamieson_table2 → wautier → srivastava                          454 / 14951 (3.0%)     1.616e+09 N·m                 39.4%
#   kim_jamieson_table2 → schottner → srivastava                        454 / 14951 (3.0%)     6.966e+07 N·m                 74.4%
#   kim_jamieson_table2 → kochle → kochle                               441 / 14951 (2.9%)     2.658e+08 N·m                 90.4%
#   kim_jamieson_table2 → bergfeld → srivastava                         414 / 14951 (2.8%)     6.850e+07 N·m                 72.9%
#   geldsetzer → bergfeld → srivastava                                  384 / 14951 (2.6%)     7.124e+07 N·m                 84.6%
#   kim_jamieson_table2 → kochle → srivastava                           345 / 14951 (2.3%)     2.824e+08 N·m                 86.1%
#   geldsetzer → kochle → srivastava                                    344 / 14951 (2.3%)     2.862e+08 N·m                 96.7%
#   kim_jamieson_table5 → schottner → kochle                             61 / 14951 (0.4%)     1.351e+08 N·m                 71.1%
#   kim_jamieson_table5 → wautier → kochle                               60 / 14951 (0.4%)     2.260e+09 N·m                 33.4%
#   kim_jamieson_table5 → wautier → srivastava                           39 / 14951 (0.3%)     1.317e+09 N·m                 30.7%
#   kim_jamieson_table5 → schottner → srivastava                         39 / 14951 (0.3%)     8.424e+07 N·m                 56.3%
#   kim_jamieson_table5 → bergfeld → srivastava                          33 / 14951 (0.2%)     3.354e+07 N·m                 50.4%
#   data_flow → wautier → kochle                                         17 / 14951 (0.1%)     4.773e+09 N·m                 23.2%
#   data_flow → schottner → kochle                                       17 / 14951 (0.1%)     3.817e+08 N·m                 45.0%
#   data_flow → wautier → srivastava                                     12 / 14951 (0.1%)     4.996e+09 N·m                 23.2%
#   data_flow → schottner → srivastava                                   12 / 14951 (0.1%)     4.741e+08 N·m                 41.7%
#   data_flow → bergfeld → srivastava                                     8 / 14951 (0.1%)     1.101e+08 N·m                 41.2%
#   data_flow → kochle → kochle                                           7 / 14951 (0.0%)     1.420e+09 N·m                 40.7%
#   kim_jamieson_table5 → kochle → kochle                                 7 / 14951 (0.0%)     1.420e+09 N·m                 40.7%
#   data_flow → bergfeld → kochle                                         6 / 14951 (0.0%)     3.611e+07 N·m                 43.5%
#   kim_jamieson_table5 → bergfeld → kochle                               6 / 14951 (0.0%)     3.611e+07 N·m                 43.5%
#   data_flow → kochle → srivastava                                       4 / 14951 (0.0%)     2.373e+09 N·m                 40.1%
#   kim_jamieson_table5 → kochle → srivastava                             4 / 14951 (0.0%)     2.373e+09 N·m                 40.1%
#
#   Note: Uncertainty is propagated from input measurement uncertainties only.
#   Slab success requires D11 calculation for the entire slab.

# %% [markdown]
# ## 4. Sankey Diagram: kim_jamieson_table2 → wautier → kochle
#
# Slabs lost at each successive step of the calculation chain for the pathway
# `kim_jamieson_table2 → wautier → kochle`.

# %%
import plotly.graph_objects as go

TARGET          = "kim_jamieson_table2 → wautier → kochle"
METHOD_DENSITY  = "kim_jamieson_table2"
METHOD_EMOD     = "wautier"
METHOD_POISSONS = "kochle"
METHOD_D11      = "weissgraeber_rosendahl"

n_start      = len(ectp_slabs)
sc           = pathway_step_counts[TARGET]

# Sequential step counts (algorithm order: density → E-mod → ν → D11)
n_density    = sc['density']     # slabs where ALL layers got density
n_e_mod      = sc['e_mod']       # slabs where ALL layers got E-mod
n_poissons   = sc['poissons']    # slabs where ALL layers got ν
n_d11        = sc['d11']         # slabs that produced a D11 value

fail_density  = n_start    - n_density
fail_e_mod    = n_density  - n_e_mod
fail_poissons = n_e_mod    - n_poissons
fail_d11      = n_poissons - n_d11

def pct(n, d): return f"{n/d:.1%}" if d else "—"

# ── Node layout ───────────────────────────────────────────────────────────
#
# Column:   0      1      2      3      4
# x pos:  0.01   0.26   0.51   0.76   0.99
#
#  0  All slabs
#  1  Pass density   (high)    2  Fail density   (low, y=0.82)
#  3  Pass E-mod     (high)    4  Fail E-mod     (y=0.72, staggered)
#  5  Pass ν         (high)    6  Fail ν         (y=0.62, staggered)
#  7  Pass D11       (high)    8  Fail D11       (y=0.72)

BLUE  = "rgba( 68, 114, 196, 0.85)"   # density
GREEN = "rgba( 84, 168, 104, 0.85)"   # E-mod
PURP  = "rgba(148, 103, 189, 0.85)"   # Poisson's ratio
RED   = "rgba(196,  84,  78, 0.85)"   # D11
GREY  = "rgba(170, 170, 170, 0.65)"   # failures

node_labels = [
    f"All slabs<br>{n_start:,}",
    f"Pass density<br>{n_density:,} ({pct(n_density, n_start)})",
    f"Fail density<br>{fail_density:,} ({pct(fail_density, n_start)})",
    f"Pass E-mod<br>{n_e_mod:,} ({pct(n_e_mod, n_start)})",
    f"Fail E-mod<br>{fail_e_mod:,} ({pct(fail_e_mod, n_density)} of pass density)",
    f"Pass ν<br>{n_poissons:,} ({pct(n_poissons, n_start)})",
    f"Fail ν<br>{fail_poissons:,} ({pct(fail_poissons, n_e_mod)} of pass E-mod)",
    f"Pass D11<br>{n_d11:,} ({pct(n_d11, n_start)})",
    f"Fail D11<br>{fail_d11:,} ({pct(fail_d11, n_poissons)} of pass ν)",
]

#           0     1     2     3     4     5     6     7     8
node_x   = [0.01, 0.26, 0.26, 0.51, 0.51, 0.76, 0.76, 0.99, 0.99]
node_y   = [0.35, 0.18, 0.82, 0.18, 0.72, 0.18, 0.62, 0.18, 0.72]
node_col = [BLUE, BLUE, GREY, GREEN, GREY, PURP, GREY, RED,  GREY]

link_source = [0, 0, 1, 1, 3, 3, 5, 5]
link_target = [1, 2, 3, 4, 5, 6, 7, 8]
link_value  = [
    n_density,   fail_density,
    n_e_mod,     fail_e_mod,
    n_poissons,  fail_poissons,
    n_d11,       fail_d11,
]
link_color  = [
    "rgba( 68, 114, 196, 0.22)",
    "rgba(170, 170, 170, 0.20)",
    "rgba( 84, 168, 104, 0.22)",
    "rgba(170, 170, 170, 0.20)",
    "rgba(148, 103, 189, 0.22)",
    "rgba(170, 170, 170, 0.20)",
    "rgba(196,  84,  78, 0.22)",
    "rgba(170, 170, 170, 0.20)",
]

fig = go.Figure(go.Sankey(
    arrangement="snap",
    node=dict(
        label=node_labels,
        x=node_x, y=node_y,
        color=node_col,
        pad=12, thickness=20,
        line=dict(color="white", width=0.5),
    ),
    link=dict(
        source=link_source, target=link_target,
        value=link_value, color=link_color,
    ),
))

# ── Method label annotations ──────────────────────────────────────────────
# Labels sit below each destination column. ax/ay are pixel offsets from
# the annotation point (arrow tip is at the label, tail points upward).
# axref/ayref must be 'pixel' in this version of Plotly.

fig.update_layout(
    title=dict(
        text=(
            f"<b>Sequential calculation chain: {TARGET}</b><br>"
            f"<sup>Algorithm order: density → elastic modulus → Poisson’s ratio → D11  —  "
            f"total: {n_start:,} ECTP slabs</sup>"
        ),
        x=0.5, xanchor="center", font=dict(size=13),
    ),
    font=dict(size=11),
    width=1000,
    height=580,
    margin=dict(l=20, r=80, t=100, b=120),
    annotations=[
        # Labels placed below each output column using paper coords;
        # arrow drawn with pixel offset (ax=0 = directly above label).
        dict(
            x=0.26, y=-0.14, xref="paper", yref="paper",
            ax=0, ay=-25, axref="pixel", ayref="pixel",
            showarrow=True, arrowhead=2, arrowsize=1, arrowwidth=1.5,
            arrowcolor="rgba(68,114,196,0.7)",
            text=f"<b>{METHOD_DENSITY}</b><br><span style='font-size:10px'>density</span>",
            font=dict(size=11, color="rgba(68,114,196,1)"), align="center",
        ),
        dict(
            x=0.51, y=-0.14, xref="paper", yref="paper",
            ax=0, ay=-25, axref="pixel", ayref="pixel",
            showarrow=True, arrowhead=2, arrowsize=1, arrowwidth=1.5,
            arrowcolor="rgba(84,168,104,0.7)",
            text=f"<b>{METHOD_EMOD}</b><br><span style='font-size:10px'>elastic modulus</span>",
            font=dict(size=11, color="rgba(84,168,104,1)"), align="center",
        ),
        dict(
            x=0.76, y=-0.14, xref="paper", yref="paper",
            ax=0, ay=-25, axref="pixel", ayref="pixel",
            showarrow=True, arrowhead=2, arrowsize=1, arrowwidth=1.5,
            arrowcolor="rgba(148,103,189,0.7)",
            text=f"<b>{METHOD_POISSONS}</b><br><span style='font-size:10px'>Poisson’s ratio</span>",
            font=dict(size=11, color="rgba(148,103,189,1)"), align="center",
        ),
        dict(
            x=0.97, y=-0.14, xref="paper", yref="paper",
            ax=0, ay=-25, axref="pixel", ayref="pixel",
            showarrow=True, arrowhead=2, arrowsize=1, arrowwidth=1.5,
            arrowcolor="rgba(196,84,78,0.7)",
            text=f"<b>{METHOD_D11}</b><br><span style='font-size:10px'>D11</span>",
            font=dict(size=11, color="rgba(196,84,78,1)"), align="center",
        ),
    ],
)

fig.show()

# %% [markdown]
# ## 5. D11 Distribution by Pathway
#
# Horizontal violin plots comparing the D11 distributions across all 32 calculation pathways.
# Pathways are ordered top-to-bottom by slab coverage (highest first). The x-axis shows D11 on a log₁₀ scale
# so that distributions spanning several orders of magnitude remain visually comparable.

# %%
import math
import plotly.graph_objects as go

# Color by density method (first component of the pathway)
DENSITY_COLORS = {
    'geldsetzer':          'rgba( 68, 114, 196, 0.75)',
    'kim_jamieson_table2': 'rgba( 84, 168, 104, 0.75)',
    'kim_jamieson_table5': 'rgba(148, 103, 189, 0.75)',
    'data_flow':           'rgba(196, 140,  68, 0.75)',
}

# Log10-transform all values to make KDE shapes meaningful across orders of magnitude
all_log_vals = np.concatenate([
    np.log10(np.array(v)[np.array(v) > 0])
    for v in pathway_nominal.values() if v
])
x_min = math.floor(np.percentile(all_log_vals, 0.5))
x_max = math.ceil(np.percentile(all_log_vals, 99.5))

# Build log10 tick labels (e.g. 10⁻², 10⁻¹, …, 10⁵)
tick_vals  = list(range(x_min, x_max + 1))
tick_texts = [f"10<sup>{v}</sup>" for v in tick_vals]

fig = go.Figure()

# sorted_pathways is descending by coverage; add in reverse so the highest-coverage
# pathway ends up at the top of the (reversed) y-axis
for pathway, n_ok in reversed(sorted_pathways):
    vals = np.array(pathway_nominal.get(pathway, []))
    vals = vals[vals > 0]
    if len(vals) == 0:
        continue

    log_vals    = np.log10(vals)
    density_m   = pathway.split(' → ')[0]
    color       = DENSITY_COLORS.get(density_m, 'rgba(128,128,128,0.7)')
    line_color  = color.replace('0.75', '1.0')
    pct         = n_ok / total_slabs

    fig.add_trace(go.Violin(
        x=log_vals,
        y=[f"{pathway}  <i>({n_ok:,} / {total_slabs:,}, {pct:.1%})</i>"] * len(log_vals),
        orientation='h',
        name=pathway,
        box_visible=True,
        meanline_visible=True,
        points=False,
        fillcolor=color,
        line_color=line_color,
        opacity=0.85,
        showlegend=False,
    ))

fig.update_layout(
    title=dict(
        text=(
            '<b>D11 Distribution by Calculation Pathway</b><br>'
            '<sup>Slab-level (ECTP) — ordered top→bottom by coverage — '
            'box shows IQR, line shows mean — colour = density method</sup>'
        ),
        x=0.5, xanchor='center', font=dict(size=13),
    ),
    xaxis=dict(
        title='D11 (N·m)',
        range=[x_min - 0.2, x_max + 0.2],
        tickvals=tick_vals,
        ticktext=tick_texts,
        gridcolor='rgba(200,200,200,0.4)',
        zeroline=False,
    ),
    yaxis=dict(
        autorange='reversed',
        tickfont=dict(size=9.5),
        ticklabelposition='outside',
    ),
    plot_bgcolor='white',
    violingap=0.06,
    violingroupgap=0,
    width=1050,
    height=1380,
    margin=dict(l=390, r=40, t=100, b=60),
)

fig.show()

# %% [markdown]
# ## 6. Fig. 7 (HESS draft) — D11 distribution across all 32 pathways
#
# Horizontal violin plots on a log₁₀ scale, ordered by slab coverage (highest first). Colour encodes the density method used. This is the headline result figure for §3.5. Saved as `figures/fig07_D11_distributions.png`.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# ── HESS figure settings ──────────────────────────────────────────────────
mpl.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['Helvetica', 'Arial', 'DejaVu Sans'],
    'font.size': 8,
    'axes.labelsize': 9,
    'xtick.labelsize': 8,
    'ytick.labelsize': 7.5,
    'legend.fontsize': 7.5,
    'axes.linewidth': 0.8,
    'grid.linewidth': 0.3,
})

DOUBLE_COL = 7.0    # inches (≈ 17.8 cm) — full-width for 32-pathway violin
DPI = 300

# ── Color palette: Wong (2011) colorblind-safe, by density method ─────────
DENSITY_COLORS = {
    'geldsetzer':          '#0072B2',   # blue
    'kim_jamieson_table2': '#009E73',   # bluish green
    'kim_jamieson_table5': '#E69F00',   # orange
    'data_flow':           '#CC79A7',   # reddish purple
}
DENSITY_LABELS = {
    'geldsetzer':          'Geldsetzer & Jamieson (2000)',
    'kim_jamieson_table2': 'Kim & Jamieson (2014) Table 2',
    'kim_jamieson_table5': 'Kim & Jamieson (2014) Table 5',
    'data_flow':           'Direct measurement',
}

# ── Build data arrays ──────────────────────────────────────────────────────
# sorted_pathways is already ordered descending by slab count
plot_data = []   # list of (pathway_label, log10_vals, density_method, n_ok)
for pathway, n_ok in sorted_pathways:
    vals = np.array(pathway_nominal.get(pathway, []))
    vals = vals[vals > 0]
    if len(vals) == 0:
        continue
    density_m = pathway.split(' → ')[0]
    pct = n_ok / total_slabs
    # Compact label: use → separators; abbreviate method names
    short = (pathway
             .replace('kim_jamieson_table2', 'kim_t2')
             .replace('kim_jamieson_table5', 'kim_t5')
             .replace('geldsetzer', 'geld')
             .replace('data_flow', 'data')
             .replace('weissgraeber_rosendahl', 'WR'))
    label = f"{short}  ({n_ok:,}, {pct:.1%})"
    plot_data.append((label, np.log10(vals), density_m, n_ok))

n_pathways = len(plot_data)

# ── Figure ────────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(DOUBLE_COL, n_pathways * 0.32 + 1.0))

y_positions = np.arange(n_pathways)

for i, (label, log_vals, density_m, n_ok) in enumerate(plot_data):
    color = DENSITY_COLORS.get(density_m, '#999999')
    # Violin
    parts = ax.violinplot(log_vals, positions=[i], vert=False,
                          showmedians=True, showextrema=False,
                          widths=0.75)
    for pc in parts['bodies']:
        pc.set_facecolor(color)
        pc.set_edgecolor(color)
        pc.set_alpha(0.55)
    parts['cmedians'].set_color(color)
    parts['cmedians'].set_linewidth(1.2)

ax.set_yticks(y_positions)
ax.set_yticklabels([d[0] for d in plot_data])
ax.invert_yaxis()   # highest coverage at top

# Log₁₀ x-axis ticks (N·m)
nm_ticks = [1e6, 1e7, 1e8, 1e9, 1e10]
ax.set_xticks([np.log10(v) for v in nm_ticks])
ax.set_xticklabels([f'10$^{{{int(np.log10(v))}}}$' for v in nm_ticks])
ax.set_xlabel('D11 (N m)')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(axis='x', linewidth=0.3, color='0.85')

# Legend for density method colors
legend_handles = [
    mpatches.Patch(facecolor=DENSITY_COLORS[m], alpha=0.65,
                   label=DENSITY_LABELS[m])
    for m in ['geldsetzer', 'kim_jamieson_table2', 'kim_jamieson_table5', 'data_flow']
]
ax.legend(handles=legend_handles, loc='lower right', frameon=False,
          handlelength=1.0, borderpad=0.4)

plt.tight_layout()
plt.savefig('figures/fig07_D11_distributions.png', dpi=DPI, bbox_inches='tight')
plt.show()
print(f"Saved figures/fig07_D11_distributions.png  ({n_pathways} pathways plotted)")
# Out:
# Saved figures/fig07_D11_distributions.png  (32 pathways plotted)
