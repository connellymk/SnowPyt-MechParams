# %% [markdown]
# # Paper Diagrams
#
# Rebuild the conceptual and methods figures used in `mech_params_paper/mkc_draft.tex`.
# All exports are written to `mech_params_paper/figures/` as PDF and PNG.

# %%
import logging
import warnings
logging.getLogger('fontTools').setLevel(logging.ERROR)
warnings.filterwarnings('ignore')

from notebook_utils import PAPER_FIGURES_DIR, hess_rcparams
from paper_figure_utils import (
    build_elastic_modulus_curves_figure,
    build_method_support_matrices_figure,
    save_paper_figure,
)
hess_rcparams()
PAPER_FIGURES_DIR
# Out:
# PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures')

# %% [markdown]
# ## Parameterization Figures
#
# These figures support the methods sections for density-method applicability and elastic modulus pathways.

# %%
method_exports = {}
method_exports['method_support_matrices'] = save_paper_figure(build_method_support_matrices_figure(), 'method_support_matrices', close=True)
method_exports['emod_theoretical_curves'] = save_paper_figure(build_elastic_modulus_curves_figure(), 'emod_theoretical_curves', close=True)
method_exports
# Out:
# {'method_support_matrices': {'repo_pdf': PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures/method_support_matrices.pdf'),
#   'repo_png': PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures/method_support_matrices.png'),
#   'external_pdf': PosixPath('/Users/marykate/Desktop/Snow/mech_params_paper/figures/method_support_matrices.pdf'),
#   'external_png': PosixPath('/Users/marykate/Desktop/Snow/mech_params_paper/figures/method_support_matrices.png'),
#   'pdf': PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures/method_support_matrices.pdf'),
#   'png': PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures/method_support_matrices.png'),
#   'external_dir': PosixPath('/Users/marykate/Desktop/Snow/mech_params_paper/figures')},
#  'emod_theoretical_curves': {'repo_pdf': PosixPath('/Users/marykate/Desktop/Snow/SnowPyt-MechParams/paper/figures/emod_theoretical_curves.pdf'),
# ...
