# %%
from parameterization_algorithm import find_parameterizations
from definitions import graph

# %%
# Find all parameterizations for a target parameter
density = graph.get_node("density")
parameterizations = find_parameterizations(graph, density)

# Print results
for i, param in enumerate(parameterizations, 1):
    print(f"Parameterization {i}:")
    print(param)
    print()
# Out:
# Parameterization 1:
# branch 1: snow_pit -> data_flow -> measured_density -> data_flow -> density
#
# Parameterization 2:
# branch 1: snow_pit -> data_flow -> measured_hand_hardness -> data_flow -> merge_hand_hardness_grain_form -> geldsetzer -> density
# branch 2: snow_pit -> data_flow -> measured_grain_form -> data_flow -> merge_hand_hardness_grain_form -> geldsetzer -> density
# merge branch 1, branch 2: merge_hand_hardness_grain_form
#
# Parameterization 3:
# branch 1: snow_pit -> data_flow -> measured_hand_hardness -> data_flow -> merge_hand_hardness_grain_form -> kim_jamieson_table2 -> density
# branch 2: snow_pit -> data_flow -> measured_grain_form -> data_flow -> merge_hand_hardness_grain_form -> kim_jamieson_table2 -> density
# merge branch 1, branch 2: merge_hand_hardness_grain_form
#
# Parameterization 4:
# branch 1: snow_pit -> data_flow -> measured_hand_hardness -> data_flow -> merge_hand_hardness_grain_form_grain_size -> kim_jamieson_table5 -> density
# branch 2: snow_pit -> data_flow -> measured_grain_form -> data_flow -> merge_hand_hardness_grain_form_grain_size -> kim_jamieson_table5 -> density
# branch 3: snow_pit -> data_flow -> measured_grain_size -> data_flow -> merge_hand_hardness_grain_form_grain_size -> kim_jamieson_table5 -> density
# merge branch 1, branch 2, branch 3: merge_hand_hardness_grain_form_grain_size
