# %% [markdown]
# # Paper Diagrams
#
# Rebuild the conceptual and methods figures used in `mech_params_paper/mkc_draft.tex`.
# All exports are written to `mech_params_paper/figures/` as PDF and PNG.

# %%
import warnings
warnings.filterwarnings('ignore')

from notebook_utils import PAPER_FIGURES_DIR, hess_rcparams
from paper_figure_utils import (
    build_density_pathways_figure,
    build_elastic_modulus_curves_figure,
    build_grain_form_hardness_ranges_figure,
    build_intro_workflow_figure,
    build_mechparams_data_model_figure,
    build_params_graph_figure,
    build_snowpylot_data_model_figure,
    save_paper_figure,
)
from snowpyt_mechparams.graph import graph

hess_rcparams()
PAPER_FIGURES_DIR

# %% [markdown]
# ## Workflow and Data Models
#
# These figures replace the prior screenshot-style diagrams with static Matplotlib exports.

# %%
workflow_exports = {}
workflow_exports['intro_flowchart'] = save_paper_figure(build_intro_workflow_figure(), 'intro_flowchart', close=True)
workflow_exports['snowpylot_data_model'] = save_paper_figure(build_snowpylot_data_model_figure(), 'snowpylot_data_model', close=True)
workflow_exports['mechparams_data_model'] = save_paper_figure(build_mechparams_data_model_figure(), 'mechparams_data_model', close=True)
workflow_exports

# %% [markdown]
# ## Parameterization Figures
#
# These figures support the methods sections for density, elastic modulus, and graph pathways.

# %%
method_exports = {}
method_exports['grain_form_hardness_ranges'] = save_paper_figure(build_grain_form_hardness_ranges_figure(), 'grain_form_hardness_ranges', close=True)
method_exports['emod_theoretical_curves'] = save_paper_figure(build_elastic_modulus_curves_figure(), 'emod_theoretical_curves', close=True)
method_exports['params_graph'] = save_paper_figure(build_params_graph_figure(graph), 'params_graph', close=True)
method_exports['density_pathways'] = save_paper_figure(build_density_pathways_figure(), 'density_pathways', close=True)
method_exports
